# %%
# Out:
# {'Error': 'No API key provided.', 'Response': 'False'}

# %%
# Import the imdb package.
import imdb

from os import listdir
from os.path import isfile, join

PATH = '/Users/guillaume_j/Movies/Film/'

movie_titles = [f for f in listdir(PATH)]

# Create the object that will be used to access the IMDb's database.
ia = imdb.IMDb() 

movies = []

for title in movie_titles:
    print('Raw movie title:', title)
    idx = title.find("-")
    title = title[:idx]
    if title != -1:
        s_result = ia.search_movie(title)
        if s_result:
            movie = s_result[0]
            print('Movie:', title)
            print('Title:', movie['title'])
            print('Date:', movie['year'])
            print('Genre:', movie['kind'])
            ia.update(movie)
            if 'director' in movie:
                print('Director:', movie['director'])
            movies.append(movie)
# Out:
# Movie title: .DS_Store
# .DS_Stor
# Movie: .DS_Stor
# Title: Solo: A Star Wars Story
# Date: 2018
# Genre: movie
# Director: [<Person id:0000165[http] name:_Howard, Ron_>]
# Movie title: A Nos Amours - Maurice Pialat (1983).mkv
# A Nos Amours
# Movie: A Nos Amours
# Title: À Nos Amours
# Date: 1983
# Genre: movie
# Director: [<Person id:0681207[http] name:_Pialat, Maurice_>]
# Movie title: A serious man - Coen Brothers (2009).mkv
# A serious man
# Movie: A serious man
# Title: A Serious Man
# Date: 2009
# Genre: movie
# Director: [<Person id:0001053[http] name:_Coen, Ethan_>, <Person id:0001054[http] name:_Coen, Joel_>]
# Movie title: Ascenseur pour l'échafaud - Agnés Varda (1957).mp4
# Ascenseur pour l'échafaud
# Movie title: Ave Cesar - Coen Brothers (2016).mkv
# Ave Cesar
# Movie: Ave Cesar
# Title: Hail Caesar
# Date: 1994
# Genre: movie
# Director: [<Person id:0001309[http] name:_Hall, Anthony Michael_>]
# Movie title: Blow Out -Brian de Palma (1981)
# Blow Out
# Movie: Blow Out
# Title: Blow Out
# Date: 1981
# Genre: movie
# Director: [<Person id:0000361[http] name:_De Palma, Brian_>]
# Movie title: Blowup - Antonioni (1966)
# Blowup
# Movie: Blowup
# Title: Blow-Up
# Date: 1966
# Genre: movie
# Director: [<Person id:0000774[http] name:_Antonioni, Michelangelo_>]
# Movie title: Bonjour Tristesse - Otto Preminger (1958)
# Bonjour Tristesse
# Movie: Bonjour Tristesse
# Title: Bonjour Tristesse
# Date: 1958
# Genre: movie
# Director: [<Person id:0695937[http] name:_Preminger, Otto_>]
# Movie title: Buffet Froid - Bertrand Blier (1979)
# Buffet Froid
# Movie: Buffet Froid
# Title: Buffet Froid
# Date: 1979
# Genre: movie
# Director: [<Person id:0088397[http] name:_Blier, Bertrand_>]
# Movie title: Capote -  Bennett Miller (2005).mkv
# Capote
# Movie: Capote
# Title: Capote
# Date: 2005
# Genre: movie
# Director: [<Person id:0587955[http] name:_Miller, Bennett_>]
# Movie title: Celine and Julie Go Boating - Jacques Rivette (1974).mkv
# Celine and Julie Go Boating
# Movie: Celine and Julie Go Boating
# Title: Celine and Julie Go Boating
# Date: 1974
# Genre: movie
# Director: [<Person id:0729626[http] name:_Rivette, Jacques_>]
# Movie title: Cléo de 5 à 7 - Agnés Varda (1962).mkv
# Cléo de 5 à 7
# Movie title: Climax - Gaspard Noé (2018).mkv
# Climax
# Movie: Climax
# Title: Climax
# Date: 2018
# Genre: movie
# Director: [<Person id:0637615[http] name:_Noé, Gaspar_>]
# Movie title: Coffee and Cigarettes - Jim Jarmush (2004)
# Coffee and Cigarettes
# Movie: Coffee and Cigarettes
# Title: Coffee and Cigarettes
# Date: 2003
# Genre: movie
# Director: [<Person id:0000464[http] name:_Jarmusch, Jim_>]
# Movie title: Coincoin et les Z'inhumains (1-4), Noir ch'est noir - Bruno Dumont (2018).mp4
# Coincoin et les Z'inhumains (1
# Movie title: Coincoin et les Z'inhumains (2-4), Les Z'inhumains - Bruno Dumont (2018).mp4
# Coincoin et les Z'inhumains (2
# Movie title: Comment je me suis disputé... (ma vie sexuelle) - Arnaud Desplechain (1996).mp4
# Comment je me suis disputé... (ma vie sexuelle)
# Movie title: Conte d'automne - Eric Rohmer (1998)
# Conte d'automne
# Movie: Conte d'automne
# Title: Autumn Tale
# Date: 1998
# Genre: movie
# Director: [<Person id:0006445[http] name:_Rohmer, Éric_>]
# Movie title: Conte d'été - Eric Rohmer(1996)
# Conte d'été
# Movie: Conte d'été
# Title: La fabrique du Conte d'ete
# Date: 2005
# Genre: movie
# Director: [<Person id:0261991[http] name:_Etchegaray, Françoise_>, <Person id:0276467[http] name:_Fieschi, Jean-André_>]
# Movie title: Conte d'hiver - Eric Rohmer (1991)
# Conte d'hiver
# Movie: Conte d'hiver
# Title: Winter's Tale
# Date: 2014
# Genre: movie
# Director: [<Person id:0326040[http] name:_Goldsman, Akiva_>]
# Movie title: Conte de Printemps - Eric Rohmer (1990)
# Conte de Printemps
# Movie: Conte de Printemps
# Title: A Tale of Springtime
# Date: 1990
# Genre: movie
# Director: [<Person id:0006445[http] name:_Rohmer, Éric_>]
# Movie title: Daft Punk Unchained -  Hervé Martin-Delpierre (2015)
# Daft Punk Unchained
# Movie: Daft Punk Unchained
# Title: Daft Punk Unchained
# Date: 2015
# Genre: movie
# Director: [<Person id:2652148[http] name:_Martin-Delpierre, Hervé_>]
# Movie title: Dare mo shiranai -  Hirokazu Kore-eda (2004).mkv
# Dare mo shiranai
# Movie: Dare mo shiranai
# Title: Nobody Knows
# Date: 2004
# Genre: movie
# Director: [<Person id:0466153[http] name:_Koreeda, Hirokazu_>]
# Movie title: Dead Man - Jim Jarmush (1995).mkv
# Dead Man
# Movie: Dead Man
# Title: Dead Man
# Date: 1995
# Genre: movie
# Director: [<Person id:0000464[http] name:_Jarmusch, Jim_>]
# Movie title: Dead Poets Society -  Peter Weir (1989)
# Dead Poets Society
# Movie: Dead Poets Society
# Title: Dead Poets Society
# Date: 1989
# Genre: movie
# Director: [<Person id:0001837[http] name:_Weir, Peter_>]
# Movie title: Dheepan - Jacques Audiard (2015)
# Dheepan
# Movie: Dheepan
# Title: Dheepan
# Date: 2015
# Genre: movie
# Director: [<Person id:0002191[http] name:_Audiard, Jacques_>]
# Movie title: Dr Strangelove - Stanley Kubrick (1964)
# Dr Strangelove
# Movie: Dr Strangelove
# Title: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# Date: 1964
# Genre: movie
# Director: [<Person id:0000040[http] name:_Kubrick, Stanley_>]
# Movie title: Dunkirk - Christopher Nolan (2017).mkv
# Dunkirk
# Movie: Dunkirk
# Title: Dunkirk
# Date: 2017
# Genre: movie
# Director: [<Person id:0634240[http] name:_Nolan, Christopher_>]
# Movie title: First Name Carmen - Jean-Luc Godard (1983)
# First Name Carmen
# Movie: First Name Carmen
# Title: First Name: Carmen
# Date: 1983
# Genre: movie
# Director: [<Person id:0000419[http] name:_Godard, Jean-Luc_>]
# Movie title: Green Book - Peter Farrelly (2018).mkv
# Green Book
# Movie: Green Book
# Title: Green Book
# Date: 2018
# Genre: movie
# Director: [<Person id:0268380[http] name:_Farrelly, Peter_>]
# Movie title: Holy Motors - Leos Carax (2012)
# Holy Motors
# Movie: Holy Motors
# Title: Holy Motors
# Date: 2012
# Genre: movie
# Director: [<Person id:0136021[http] name:_Carax, Leos_>]
# Movie title: House Of Flying Daggers - Zhang Yimou (2004).mkv
# House Of Flying Daggers
# Movie: House Of Flying Daggers
# Title: House of Flying Daggers
# Date: 2004
# Genre: movie
# Director: [<Person id:0955443[http] name:_Zhang, Yimou_>]
# Movie title: I, Daniel Blake - Ken Loach (2016).mkv
# I, Daniel Blake
# Movie: I, Daniel Blake
# Title: I, Daniel Blake
# Date: 2016
# Genre: movie
# Director: [<Person id:0516360[http] name:_Loach, Ken_>, <Person id:8078611[http] name:_Obiols, Laura_>]
# Movie title: Irreversible - Gaspard Noé (2002)
# Irreversible
# Movie: Irreversible
# Title: Irreversible
# Date: 2002
# Genre: movie
# Director: [<Person id:0637615[http] name:_Noé, Gaspar_>]
# Movie title: Isle of Dogs - Wes Andersson(2018).mkv
# Isle of Dogs
# Movie: Isle of Dogs
# Title: Isle of Dogs
# Date: 2018
# Genre: movie
# Director: [<Person id:0027572[http] name:_Anderson, Wes_>]
# Movie title: Je T'aime Je T'aime - Alain Resnais (1968).mkv
# Je T'aime Je T'aime
# Movie: Je T'aime Je T'aime
# Title: Je t'aime, je t'aime
# Date: 1968
# Genre: movie
# Director: [<Person id:0720297[http] name:_Resnais, Alain_>]
# Movie title: Jules et Jim - Francois Truffault (1962)
# Jules et Jim
# Movie: Jules et Jim
# Title: Jules and Jim
# Date: 1962
# Genre: movie
# Director: [<Person id:0000076[http] name:_Truffaut, François_>]
# Movie title: Juste la fin du Monde - Xavier Dolan (2016).mkv
# Juste la fin du Monde
# Movie: Juste la fin du Monde
# Title: It's Only the End of the World
# Date: 2016
# Genre: movie
# Director: [<Person id:0230859[http] name:_Dolan, Xavier_>]
# Movie title: Kramer contre kramer -  Robert Benton (1979).mkv
# Kramer contre kramer
# Movie: Kramer contre kramer
# Title: Kramer vs. Kramer
# Date: 1979
# Genre: movie
# Director: [<Person id:0000914[http] name:_Benton, Robert_>]
# Movie title: L'ami de mon amie - Eric Rohmer (1987)
# L'ami de mon amie
# Movie: L'ami de mon amie
# Title: Boyfriends and Girlfriends
# Date: 1987
# Genre: movie
# Director: [<Person id:0006445[http] name:_Rohmer, Éric_>]
# Movie title: L'amour l'apres midi - Eric Rohmer (1972)
# L'amour l'apres midi
# Movie: L'amour l'apres midi
# Title: Chloe in the Afternoon
# Date: 1972
# Genre: movie
# Director: [<Person id:0006445[http] name:_Rohmer, Éric_>]
# Movie title: L'année Dernière a Marienbad - Alain Resnais (1961).mkv
# L'année Dernière a Marienbad
# Movie title: L'arbre, le maire et la médiathèque - Eric Rohmer (1993)
# L'arbre, le maire et la médiathèque
# Movie title: L'Armée des Ombres - Jean-Pierre Melville (1969)
# L'Armée des Ombres
# Movie: L'Armée des Ombres
# Title: L'armée des ombres
# Date: 1998
# Genre: episode
# Director: [<Person id:5339279[http] name:_Ferré, Dominique_>]
# Movie title: L'Homme De Rio - Philippe de Broca (1964)
# L'Homme De Rio
# Movie: L'Homme De Rio
# Title: That Man from Rio
# Date: 1964
# Genre: movie
# Director: [<Person id:0003606[http] name:_de Broca, Philippe_>]
# Movie title: L'odeur de la papaye verte -  Tran Anh Hung (1993).mkv
# L'odeur de la papaye verte
# Movie: L'odeur de la papaye verte
# Title: The Scent of Green Papaya
# Date: 1993
# Genre: movie
# Director: [<Person id:0870841[http] name:_Tran, Anh Hung_>]
# Movie title: La ballade de Buster Scruggs - Coen Brothers (2018).mkv
# La ballade de Buster Scruggs
# Movie: La ballade de Buster Scruggs
# Title: The Ballad of Buster Scruggs
# Date: 2018
# Genre: movie
# Director: [<Person id:0001053[http] name:_Coen, Ethan_>, <Person id:0001054[http] name:_Coen, Joel_>]
# Movie title: La Boulangère de Monceau - Eric Rohmer (19xx).mkv
# La Boulangère de Monceau
# Movie title: La carrière de Suzanne - Eric Rohmer (1963).avi
# La carrière de Suzanne
# Movie title: La Collectionneuse - Eric Rohmer (1967).mkv
# La Collectionneuse
# Movie: La Collectionneuse
# Title: La Collectionneuse
# Date: 1967
# Genre: movie
# Director: [<Person id:0006445[http] name:_Rohmer, Éric_>]
# Movie title: La femme de l'aviateur - Eric Rohmer (1980)
# La femme de l'aviateur
# Movie: La femme de l'aviateur
# Title: The Aviator's Wife
# Date: 1981
# Genre: movie
# Director: [<Person id:0006445[http] name:_Rohmer, Éric_>]
# Movie title: La Fureur de vivre -  Nicholas Ray (1955).mkv
# La Fureur de vivre
# Movie: La Fureur de vivre
# Title: Rebel Without a Cause
# Date: 1955
# Genre: movie
# Director: [<Person id:0712947[http] name:_Ray, Nicholas_>]
# Movie title: La grande bellezza - Paolo Sorentino (2013).mkv
# La grande bellezza
# Movie: La grande bellezza
# Title: The Great Beauty
# Date: 2013
# Genre: movie
# Director: [<Person id:0815204[http] name:_Sorrentino, Paolo_>]
# Movie title: La Nuit Americaine - Francois Truffault (1973).mkv
# La Nuit Americaine
# Movie: La Nuit Americaine
# Title: Day for Night
# Date: 1973
# Genre: movie
# Director: [<Person id:0000076[http] name:_Truffaut, François_>]
# Movie title: La Rose Pourpre du Caire - Woody Allen (1985).mkv
# La Rose Pourpre du Caire
# Movie: La Rose Pourpre du Caire
# Title: The Purple Rose of Cairo
# Date: 1985
# Genre: movie
# Director: [<Person id:0000095[http] name:_Allen, Woody_>]
# Movie title: Le beau mariage - Eric Rohmer (1982)
# Le beau mariage
# Movie: Le beau mariage
# Title: A Good Marriage
# Date: 1982
# Genre: movie
# Director: [<Person id:0006445[http] name:_Rohmer, Éric_>]
# Movie title: Le genou de claire- Eric Rohmer (1970)
# Le genou de claire
# Movie: Le genou de claire
# Title: Claire's Knee
# Date: 1970
# Genre: movie
